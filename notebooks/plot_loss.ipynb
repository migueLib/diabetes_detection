# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import pandas as pd

# %%
# Set Working directory
os.chdir(os.path.dirname(os.getcwd()))
os.getcwd()
# Out:
# '/home/ubuntu/diabetes_detection'

# %%
# Import local libraries
from src.plot_loss import plot_loss

# %%
# Load files
with open("output/diabetes_ukkb-raw-4da-cs1536-ims800x800_iv3-e100-bs16-lrv01-m9_results_copy.pkl", "rb") as IN:
    res = pickle.load(IN)
    
loss = {
    "train":res['train_loss'],
    "validation":res['validation_loss']
}
loss=pd.DataFrame(loss)

# %%
pt = plot_loss(loss["train"])

# %%
pt=v = plot_loss(loss["validation"])
